# %%
import numpy as np

data = np.load(r"D:\桌面\面波压制\深层数据面波压制\原始炮集\real_data_gather001.npy")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.imshow(
    data,
    cmap='seismic',
    aspect='auto'
)

plt.colorbar()

plt.xlabel("Trace")
plt.ylabel("Time")

plt.show()
